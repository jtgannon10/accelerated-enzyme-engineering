# %% [markdown]
# ## The following notebook can be used to make predictions for the 7 additional amide products found in Fig. 5

# %%
import sys
import src.AugmentedMLDE_Class as mlde

# %% [markdown]
# ###### Itopride:

# %%
#Itopride training and predictions
ito_training_data = r'data\HSS\itopride_train.xlsx'
ito_ec = r'data\zero-shot_predictions\itopride_zeroshot_EC.csv'
ito = mlde.AugmentedMLDEmodel(ito_training_data, None, 4, ito_ec, None, None)
ito.train_and_predict('AugmentedEC', 'Georgiev')
ito._predictions_df.sort_values("Prediction", ascending=False)[0:24]
# Out:
# Fitting 100 folds for each of 100 candidates, totalling 10000 fits
#        Mutation  Prediction
# 29380      EQLA    1.979583
# 29385      EQLG    1.940382
# 77380      LQLA    1.893030
# 77385      LQLG    1.870415
# 133380     TQLA    1.857177
# 133385     TQLG    1.826772
# 61380      IQLA    1.817824
# 37380      FQLA    1.817299
# 109380     QQLA    1.798482
# 61385      IQLG    1.782720
# 29390      EQLM    1.768882
# 37385      FQLG    1.768789
# 5380       AQLA    1.768341
# 157380     YQLA    1.763203
# 109385     QQLG    1.759377
# 101380     PQLA    1.755781
# 125380     SQLA    1.750005
# 13380      CQLA    1.739959
# 141380     VQLA    1.728785
# 53380      HQLA    1.726537
# 5385       AQLG    1.718510
# 157385     YQLG    1.718330
# 101385     PQLG    1.715397
# 13385      CQLG    1.708348

# %% [markdown]
# ###### Cinchocaine:

# %%
#Cinchocaine training and predictions
cin_training_data = r'data\HSS\cinchocaine_train.xlsx'
cin_ec = r'data\zero-shot_predictions\cinchocaine_zeroshot_EC.csv'
cin = mlde.AugmentedMLDEmodel(cin_training_data, None, 4, cin_ec, None, None)
cin.train_and_predict('AugmentedEC', 'Georgiev')
cin._predictions_df.sort_values("Prediction", ascending=False)[0:24]
# Out:
# Fitting 100 folds for each of 100 candidates, totalling 10000 fits
#        Mutation  Prediction
# 124097     SMFV    5.091107
# 124093     SMFQ    4.993975
# 124096     SMFT    4.655231
# 124091     SMFN    4.494958
# 124087     SMFI    4.449455
# 123697     SLFV    4.418234
# 120097     SAFV    4.395494
# 124089     SMFL    4.330400
# 124080     SMFA    4.318165
# 120093     SAFQ    4.298449
# 123693     SLFQ    4.294351
# 124085     SMFG    4.157000
# 124397     SMYV    4.142979
# 126097     SSFV    4.096176
# 124094     SMFR    4.057792
# 124090     SMFM    4.045347
# 124393     SMYQ    4.032170
# 126093     SSFQ    4.005468
# 124277     SMQV    4.001836
# 120497     SCFV    3.992242
# 123696     SLFT    3.976147
# 120096     SAFT    3.959806
# 126497     STFV    3.951847
# 124095     SMFS    3.948723

# %% [markdown]
# ###### Declopramide:

# %%
#Declopramide training and predictions
dec_training_data = r'data\HSS\declopramide_train.xlsx'
dec_ec = r'data\zero-shot_predictions\declopramide_zeroshot_EC.csv'
dec = mlde.AugmentedMLDEmodel(dec_training_data, None, 4, dec_ec, None, None)
dec.train_and_predict('AugmentedEC', 'Georgiev')
dec._predictions_df.sort_values("Prediction", ascending=False)[0:24]
# Out:
# Fitting 100 folds for each of 100 candidates, totalling 10000 fits
#        Mutation  Prediction
# 158295     YSRS    1.515928
# 158215     YSMS    1.482927
# 158355     YSVS    1.460798
# 158395     YSYS    1.453499
# 159095     YVRS    1.438849
# 158055     YSDS    1.421007
# 150295     WSRS    1.410328
# 158375     YSWS    1.410016
# 158095     YSFS    1.409773
# 159015     YVMS    1.405370
# 158275     YSQS    1.386322
# 159155     YVVS    1.383062
# 150215     WSMS    1.377795
# 159895     YYRS    1.376825
# 159195     YVYS    1.376252
# 94295      NSRS    1.375665
# 70295      KSRS    1.374897
# 158135     YSHS    1.365046
# 158075     YSES    1.363788
# 158175     YSKS    1.363636
# 150355     WSVS    1.355574
# 150395     WSYS    1.347794
# 78295      LSRS    1.345473
# 158035     YSCS    1.345083

# %% [markdown]
# ###### Trimethobenzamide:

# %%
#Trimethobenzamide training and predictions
tri_training_data = r'data\HSS\trimethobenzamide_train.xlsx'
tri_ec = r'data\zero-shot_predictions\trimethobenzamide_zeroshot_EC.csv'
tri = mlde.AugmentedMLDEmodel(tri_training_data, None, 4, tri_ec, None, None)
tri.train_and_predict('AugmentedEC', 'Georgiev')
tri._predictions_df.sort_values("Prediction", ascending=False)[0:24]
# Out:
# Fitting 100 folds for each of 100 candidates, totalling 10000 fits
#        Mutation  Prediction
# 73397      LELV    1.955831
# 137397     VELV    1.942574
# 137394     VELR    1.917410
# 73394      LELR    1.908488
# 73380      LELA    1.854699
# 73396      LELT    1.846533
# 137380     VELA    1.833327
# 137396     VELT    1.829002
# 74997      LILV    1.811151
# 57394      IELR    1.789277
# 137387     VELI    1.787003
# 57397      IELV    1.785973
# 73387      LELI    1.784381
# 121397     SELV    1.783852
# 73797      LFLV    1.778469
# 121394     SELR    1.776572
# 77397      LQLV    1.775741
# 138997     VILV    1.775700
# 74994      LILR    1.752369
# 77394      LQLR    1.746441
# 129397     TELV    1.743969
# 138994     VILR    1.739096
# 137797     VFLV    1.734693
# 72197      LALV    1.733912

# %% [markdown]
# ###### Sulpiride:

# %%
#Sulpiride training and predictions
sul_training_data = r'data\HSS\sulpiride_train.xlsx'
sul_ec = r'data\zero-shot_predictions\sulpiride_zeroshot_EC.csv'
sul = mlde.AugmentedMLDEmodel(sul_training_data, None, 4, sul_ec, None, None)
sul.train_and_predict('AugmentedEC', 'Georgiev')
sul._predictions_df.sort_values("Prediction", ascending=False)[0:24]
# Out:
# Fitting 100 folds for each of 100 candidates, totalling 10000 fits
#        Mutation  Prediction
# 62496      ITFT    3.052684
# 62596      ITLT    3.048401
# 62497      ITFV    2.920630
# 62616      ITMT    2.887765
# 62597      ITLV    2.880049
# 62516      ITGT    2.853430
# 126496     STFT    2.822922
# 62493      ITFQ    2.807319
# 126596     STLT    2.796084
# 134496     TTFT    2.795283
# 62593      ITLQ    2.792607
# 134596     TTLT    2.774404
# 62517      ITGV    2.725712
# 62756      ITVT    2.722040
# 62736      ITTT    2.721215
# 62617      ITMV    2.718821
# 62416      ITAT    2.715617
# 62580      ITLA    2.710569
# 62480      ITFA    2.704729
# 134497     TTFV    2.686420
# 126497     STFV    2.682686
# 126516     STGT    2.644767
# 62676      ITQT    2.638824
# 126616     STMT    2.637086

# %% [markdown]
# ###### Procainamide:

# %%
#Procainamide training and predictions
pro_training_data = r'data\HSS\procainamide_train.xlsx'
pro_ec = r'data\zero-shot_predictions\procainamide_zeroshot_EC.csv'
pro = mlde.AugmentedMLDEmodel(pro_training_data, None, 4, pro_ec, None, None)
pro.train_and_predict('AugmentedEC', 'Georgiev')
pro._predictions_df.sort_values("Prediction", ascending=False)[0:24]
# Out:
# Fitting 100 folds for each of 100 candidates, totalling 10000 fits
#        Mutation  Prediction
# 126615     STMS    1.698243
# 14615      CTMS    1.642312
# 126605     STMG    1.578440
# 126616     STMT    1.540999
# 14605      CTMG    1.526319
# 14616      CTMT    1.483185
# 126495     STFS    1.483087
# 14495      CTFS    1.427917
# 126600     STMA    1.399872
# 126485     STFG    1.371000
# 14600      CTMA    1.336935
# 126496     STFT    1.323814
# 14485      CTFG    1.319640
# 126795     STYS    1.274280
# 14496      CTFT    1.266761
# 126515     STGS    1.259602
# 126595     STLS    1.254783
# 120215     SAMS    1.241389
# 14515      CTGS    1.238887
# 14595      CTLS    1.231992
# 126415     STAS    1.226703
# 126675     STQS    1.226337
# 14795      CTYS    1.223320
# 8215       CAMS    1.187903

# %% [markdown]
# ###### Troxipide:

# %%
#Troxipide training and predictions
tro_training_data = r'data\HSS\troxipide_train.xlsx'
tro_ec = r'data\zero-shot_predictions\troxipide_zeroshot_EC.csv'
tro = mlde.AugmentedMLDEmodel(tro_training_data, None, 4, tro_ec, None, None)
tro.train_and_predict('AugmentedEC', 'Georgiev')
tro._predictions_df.sort_values("Prediction", ascending=False)[0:24]
# Out:
# Fitting 100 folds for each of 100 candidates, totalling 10000 fits
#        Mutation  Prediction
# 139937     VLTV    1.871249
# 139934     VLTR    1.820505
# 139920     VLTA    1.742410
# 139936     VLTT    1.739833
# 139927     VLTI    1.659380
# 115937     RLTV    1.630724
# 123937     SLTV    1.616895
# 115934     RLTR    1.596137
# 139933     VLTQ    1.586591
# 75937      LLTV    1.586412
# 139935     VLTS    1.565428
# 123934     SLTR    1.559945
# 139931     VLTN    1.551259
# 75934      LLTR    1.543314
# 139717     VLGV    1.540076
# 3937       ALTV    1.518958
# 83937      MLTV    1.508878
# 139617     VLAV    1.492511
# 115936     RLTT    1.491276
# 115920     RLTA    1.486694
# 139929     VLTL    1.486045
# 139714     VLGR    1.480248
# 123920     SLTA    1.472939
# 75920      LLTA    1.467969
